# %%
from cmdstanpy import CmdStanModel
import arviz as az

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dani di questo mi serve serve waic e loo

# %%
dp_mix_stan = """
data
{
    int I; // number of areal locations
    int T; // number of time steps
    int P; // number of covariates
    
    array[I] vector[T] y; // value of interest
    array[I] matrix[T,P+1] X; // covariates matrices for each province
      
    // hyperpar vector of regressors
    vector[P+1] mu_0; 
    real        sigma_0;
    
    // mean of w_1 (random effect for every province at time 1)
    vector[I] mu_w_1;
    
    // tau^2
    real a_tau2;
    real b_tau2;
    
    // sigma^2
    real a_sigma2;
    real b_sigma2;
    
    // proximity matrix
    matrix[I,I] W_raw;
    
}

transformed data
{
    vector[T] ones_T;
    for (t in 1:T)
        ones_T[t] = 1;
    
    matrix[T,T] eye_T = diag_matrix(ones_T);
 
    vector[I] ones_I;
    for (i in 1:I)
        ones_I[i] = 1;
    
    matrix[I,I] eye_I;
    eye_I = diag_matrix(ones_I);
        
    matrix[I,I] W;
    W = diag_matrix(W_raw*ones_I) - W_raw;
}

parameters
{
    real<lower=0> sigma2; 
    real<lower=0> tau2; 
    real<lower=0,upper=1> rho_t;
    real<lower=0,upper=1> rho_s;
    
    // beta
    vector[P+1] beta;

    // random effects tmp
    matrix[I,T]  ws_tmp;
    
}

transformed parameters
{   
    // Stan wants std
    real sigma = sqrt(sigma2);
    
    matrix[I,I] inv_Q = inverse_spd(rho_s*W + (1-rho_s)*eye_I);
    
    matrix[T,I]   ws = (ws_tmp)'; //otherwise I have to transpose in the for loop at each iteration
}

model
{
    sigma2 ~ inv_gamma(a_sigma2,b_sigma2);
    tau2   ~ inv_gamma(a_tau2,b_tau2); 
    rho_t  ~ uniform(0,1);
    rho_s  ~ uniform(0,1);
    
    ws_tmp[1:I,1] ~ multi_normal(mu_w_1, tau2*inv_Q);
    
    for (t in 2:T)
        ws_tmp[1:I,t] ~ multi_normal(rho_t*ws_tmp[1:I,t-1], tau2*inv_Q);
    
    beta ~ normal(mu_0, sigma_0);
    
    for (i in 1:I) {
        
        y[i] ~ normal(X[i]*beta + ws[1:T,i], sigma);
    
    }
}

generated quantities 
{   
    // log likelihood for each areal location 
    vector[I] log_lik;
    
    for (i in 1:I) 
    {
        log_lik[i] = normal_lpdf(y[i] | X[i]*beta + ws[1:T,i], sigma);
    }
    
}
"""

stan_file = "stan_files/Sp_corr.stan"

with open(stan_file, "w") as fp:
    fp.write(dp_mix_stan)
    
dp_mix = CmdStanModel(stan_file=stan_file)
# Out:
# 15:10:13 - cmdstanpy - INFO - compiling stan file /home/daan/bayesian-project/stan_files/Sp_corr.stan to exe file /home/daan/bayesian-project/stan_files/Sp_corr
# 15:10:35 - cmdstanpy - INFO - compiled model executable: /home/daan/bayesian-project/stan_files/Sp_corr

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("data/FeconditaFinale.csv", "rb") as f:
    dataset=pd.read_csv(f)
    
dataset = dataset.sort_values(by=['Territorio', 'TIME']) # the proximity matrix is built with the prov in alphabetic order
dataset
# Out:
#     Territorio  TIME  età.media.delle.madri.al.parto  \
# 930  Agrigento  2011                           30.94
# 931  Agrigento  2012                           30.73
# 932  Agrigento  2013                           31.09
# 933  Agrigento  2014                           30.99
# 934  Agrigento  2015                           31.14
# ..         ...   ...                             ...
# 625    Viterbo  2016                           31.99
# 626    Viterbo  2017                           32.17
# 627    Viterbo  2018                           32.05
# 628    Viterbo  2019                           31.97
# 629    Viterbo  2020                           32.38
#
#      età.media.dei.padri.alla.nascita.del.figlio  tasso.di.fecondità.totale  \
# 930                                        34.80                       1.37
# 931                                        34.57                       1.35
# 932                                        34.78                       1.27
# ...

# %%
Y=np.array(dataset["tasso.di.fecondità.totale"])

print(np.var(Y))
print(np.mean(Y))


y = []
y_tmp = np.zeros(10)
for prov in np.unique(dataset["Territorio"]):
    data_prov = dataset[dataset["Territorio"] == prov]
    y_tmp = np.array(data_prov["tasso.di.fecondità.totale"])
    y.append(y_tmp)
y = np.array(y)
print(y)
print(y.shape)
plt.hist(Y)  
plt.show()
# Out:
# 0.015125712353150588
# 1.3187169811320756
# [[1.37 1.35 1.27 ... 1.29 1.24 1.26]
#  [1.37 1.36 1.3  ... 1.22 1.17 1.15]
#  [1.44 1.43 1.36 ... 1.24 1.21 1.21]
#  ...
#  [1.28 1.36 1.24 ... 1.29 1.25 1.3 ]
#  [1.51 1.53 1.47 ... 1.39 1.33 1.34]
#  [1.31 1.31 1.23 ... 1.2  1.11 1.09]]
# (106, 10)

# %%
X1=np.array(dataset["età.media.delle.madri.al.parto"])
X2=np.array(dataset["tasso.di.inattività.delle.femmine"])
X3=np.array(dataset["tasso.di.inattività.dei.maschi"])
X4=np.array(dataset["tasso.di.occupazione.delle.femmine"])
X5=np.array(dataset["tasso.di.occupazione.dei.maschi"])
fig,axs = plt.subplots(5)
axs[0].hist(X1)
axs[1].hist(X2)
axs[2].hist(X3)
axs[3].hist(X4)
axs[4].hist(X5)
plt.show()

# %%
# standardization on X
X1 = (X1-np.mean(X1))/np.sqrt(np.var(X1))
X2 = (X2-np.mean(X2))/np.sqrt(np.var(X2))
X3 = (X3-np.mean(X3))/np.sqrt(np.var(X3))
X4 = (X4-np.mean(X4))/np.sqrt(np.var(X4))
X5 = (X5-np.mean(X5))/np.sqrt(np.var(X5))

#Standardization on y
y= (y-np.mean(y))/np.sqrt(np.var(y))

plt.hist(X5)
plt.show()

# %%
P = 5
X=np.ones((1060,P+1))

X[:,1]=X1
X[:,2]=X2
X[:,3]=X3
X[:,4]=X4
X[:,5]=X5

X_r = np.reshape(X,(106,10,P+1))

print(X_r)
X_r.shape
# Out:
# [[[ 1.         -1.38733389  2.05144371  0.30656436 -1.81625192
#    -0.81711788]
#   [ 1.         -1.77061906  1.89211824  0.5393075  -1.7347706
#    -1.14081907]
#   [ 1.         -1.11355877  1.78561354  1.09128765 -1.80907835
#    -1.41912648]
#   ...
#   [ 1.         -0.18272337  1.69594042  0.33345848 -2.07454665
#    -1.43529694]
#   [ 1.         -0.29223342  1.66432349  0.72523738 -1.76815191
#    -1.50014603]
#   [ 1.         -0.03670997  1.78846129  1.48582068 -1.84282015
#    -1.66422814]]
#
#  [[ 1.         -1.64285734 -0.34660173  0.24677987  0.51836657
#     0.15248205]
#   [ 1.         -1.27782385 -0.71508174 -0.21575525  0.60314497
#     0.12708264]
#   [ 1.         -0.73027361 -0.41062779  0.02698863  0.15451856
#     0.059098  ]
#   ...
#   [ 1.         -0.20097504 -0.48714728 -0.31928696  0.46379505
#     0.19264358]
#   [ 1.          0.03629673 -0.3382982  -0.29482666  0.27341734
#     0.41537872]
#   [ 1.          0.10930342 -0.19435256  0.16948911  0.17544987
# ...

# %%
I= 106
T= 10

# %%
with open("data/Proximity_matrix_finale.csv", "rb") as f:
    W_raw=pd.read_csv(f)

# %%
W_raw=np.matrix(W_raw)

# %%
for i in range(106):
  W_raw[i,i] = 0

# %%
mu_0 = np.zeros(P+1) #as in the paper
mu_w_1 = np.zeros(I) #as in the paper
sigma_0 = 1 #covariance matrix
H = 10

data = {
    "I": I,
    "T": T,
    "P": P,
    "y": y,
    "X": X_r,
    "mu_0": mu_0,
    "sigma_0": sigma_0,
    "mu_w_1": mu_w_1,
    "a_tau2": 3,
    "b_tau2": 2,
    "a_sigma2": 3,
    "b_sigma2": 2,
    "W_raw": W_raw
}

# %%
fit = dp_mix.sample(data
                    , iter_warmup = 100
                    , iter_sampling = 100
                    , show_console = True)
# Out:
# 15:13:04 - cmdstanpy - INFO - Chain [1] start processing
# 15:13:04 - cmdstanpy - INFO - Chain [2] start processing
# 15:13:04 - cmdstanpy - INFO - Chain [3] start processing
# 15:13:04 - cmdstanpy - INFO - Chain [4] start processing
# Chain [2] method = sample (Default)
# Chain [2] sample
# Chain [2] num_samples = 100
# Chain [2] num_warmup = 100
# Chain [2] save_warmup = 0 (Default)
# Chain [2] thin = 1 (Default)
# Chain [2] adapt
# Chain [2] engaged = 1 (Default)
# Chain [2] gamma = 0.050000000000000003 (Default)
# Chain [2] delta = 0.80000000000000004 (Default)
# Chain [2] kappa = 0.75 (Default)
# Chain [2] t0 = 10 (Default)
# Chain [2] init_buffer = 75 (Default)
# Chain [2] term_buffer = 50 (Default)
# Chain [2] window = 25 (Default)
# Chain [2] algorithm = hmc (Default)
# Chain [2] hmc
# Chain [2] engine = nuts (Default)
# Chain [2] nuts
# Chain [2] max_depth = 10 (Default)
# Chain [2] metric = diag_e (Default)
# Chain [2] metric_file =  (Default)
# ...

# %%
fit_az = az.from_cmdstanpy(fit)

# %%
az.plot_trace(fit_az,var_names=["beta"], compact = False)
plt.show()

# %%
az.plot_trace(fit_az,var_names=["rho_t"], compact = False)
plt.show()

# %%
az.plot_trace(fit_az,var_names=["rho_s"], compact = False)
plt.show()

# %%
az.waic(fit_az)

# %%
az.loo(fit_az)
